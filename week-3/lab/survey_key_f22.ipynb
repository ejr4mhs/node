# %% [markdown]
# # Lab 03 - Let's explore the data from the intro survey!
# Start by importing the necessary libraries (pandas)

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np

# %% [markdown]
# Next, let's read in the data. This time, we'll be working with two csv files. Make sure to name them different things!
#
# URL1: `https://raw.githubusercontent.com/dt3zjy/node/master/week-3/lab/survey_responses_f22.csv`
# <br>URL2: `https://raw.githubusercontent.com/dt3zjy/node/master/week-3/lab/survey_names_f22.csv`

# %%
# Read in the data from both csv files
df1 = pd.read_csv("https://raw.githubusercontent.com/dt3zjy/node/master/week-3/lab/survey_responses_f22.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/dt3zjy/node/master/week-3/lab/survey_names_f22.csv")

# %% [markdown]
# Let's see what's in the data we just imported

# %%
# Check out both DataFrames
df1.head()
# Out:
#    Index           Timestamp Preferred Pronouns  \
# 0      0  9/18/2022 13:59:07             He/Him
# 1      1  9/18/2022 13:59:24             he/him
# 2      2  9/18/2022 13:59:39             He/him
# 3      3  9/18/2022 13:59:49                 He
# 4      4  9/18/2022 14:01:32       she/her/hers
#
#   What college are you in? (If not UVA, put your school) What year are you?  \
# 0                       College of Arts and Sciences               3rd Year
# 1                                   Arts and Sciecne               3rd Year
# 2                        McIntire School of Commerce               3rd Year
# 3                                    Arts & Sciences                    NaN
# 4                       College of Arts and Sciences               4th Year
#
#   My planned (or declared) major is... (Separate each by commas)  \
# 0        Economics (Minors: CS and Business Spanish)
# 1                                            Physics
# 2                                         Finance/IT
# 3                       Computer Science + Economics
# 4                       Computer Science, Math minor
#
#    Are you new to CS How I feel about... [Python] How I feel about... [R]  \
# 0                 No                Kinda know it          Never tried it
# 1  It's been a while                      Love it          Never tried it
# 2                Yes               Never tried it          Never tried it
# 3                 No                Kinda know it           Kinda know it
# 4                 No        Love it, Know it well          Never tried it
#
#   How I feel about... [SQL] How I feel about... [SAS/STATA]  \
# 0            Never tried it                   Kinda know it
# 1            Never tried it                  Never tried it
# 2            Never tried it                  Never tried it
# 3             Kinda know it                   Kinda know it
# 4             Kinda know it                  Never tried it
#
#   How I feel about... [Other Languages] How I feel about... [Statistics]  \
# 0                         Kinda know it                    Kinda know it
# 1                         Kinda know it                    Kinda know it
# 2                         Kinda know it                    Kinda know it
# 3                         Kinda know it                    Kinda know it
# 4                                   NaN                    Kinda know it
#
#                              I'm passionate about...  \
# 0                                                NaN
# 1                                   Tech and Finance
# 2  New York Jets, playing sports, learning as muc...
# 3                                                NaN
# 4                                          good food
#
#                            Some of my hobbies are...  \
# 0  Soccer, traveling, fitness, spending time outside
# 1               Mountain biking, working out, gaming
# 2             Tennis, golf, basketball, poker, chess
# 3                                   Nature, podcasts
# 4                           hiking, painting, skiing
#
#                         I'm most excited to learn...  \
# 0  How to be more proficient in python and data s...
# 1                                   Machine Learning
# 2  How to transcend large data sets into meaningf...
# 3                                      Data Science!
# 4                        machine learning algorithms
#
#   Can we use your responses to this form for a class activity?  \
# 0                                                Yes
# 1                                                Yes
# 2                                Yes, but anonymized
# 3                                Yes, but anonymized
# 4                                                Yes
#
#          Any food allergies?  \
# 0                        NaN
# 1  Can't eat cow of pig meat
# 2                         No
# 3                        NaN
# 4                       Nope
#
#                              Any questions/concerns?
# 0                                                NaN
# 1                                                NaN
# 2  Concerned that I may need a little bit of extr...
# 3                                                NaN
# 4                                  Not at the moment

# %%
df2.head()
# Out:
#    Index First Name     Last Name Preferred name (if different)
# 0      0      Henry       Brorsen                           NaN
# 1      1    Venkata  Panchumarthy                        Sujith
# 2      2       Whit         Stahl                           NaN
# 3      3       Syed   Hasan-Aamir                         Ahmad
# 4      4  Francesca     Pirozzoli                        Franny

# %% [markdown]
# It looks like the data is all from the same form, but the name columns got separated from the rest of the info. Merge the two dataframes

# %%
# Merge on the Index column
df = pd.merge(df1, df2, on="Index", how="outer")
df.head()
# Out:
#    Index           Timestamp Preferred Pronouns  \
# 0      0  9/18/2022 13:59:07             He/Him
# 1      1  9/18/2022 13:59:24             he/him
# 2      2  9/18/2022 13:59:39             He/him
# 3      3  9/18/2022 13:59:49                 He
# 4      4  9/18/2022 14:01:32       she/her/hers
#
#   What college are you in? (If not UVA, put your school) What year are you?  \
# 0                       College of Arts and Sciences               3rd Year
# 1                                   Arts and Sciecne               3rd Year
# 2                        McIntire School of Commerce               3rd Year
# 3                                    Arts & Sciences                    NaN
# 4                       College of Arts and Sciences               4th Year
#
#   My planned (or declared) major is... (Separate each by commas)  \
# 0        Economics (Minors: CS and Business Spanish)
# 1                                            Physics
# 2                                         Finance/IT
# 3                       Computer Science + Economics
# 4                       Computer Science, Math minor
#
#    Are you new to CS How I feel about... [Python] How I feel about... [R]  \
# 0                 No                Kinda know it          Never tried it
# 1  It's been a while                      Love it          Never tried it
# 2                Yes               Never tried it          Never tried it
# 3                 No                Kinda know it           Kinda know it
# 4                 No        Love it, Know it well          Never tried it
#
#   How I feel about... [SQL]  ... How I feel about... [Statistics]  \
# 0            Never tried it  ...                    Kinda know it
# 1            Never tried it  ...                    Kinda know it
# 2            Never tried it  ...                    Kinda know it
# 3             Kinda know it  ...                    Kinda know it
# 4             Kinda know it  ...                    Kinda know it
#
#                              I'm passionate about...  \
# 0                                                NaN
# 1                                   Tech and Finance
# 2  New York Jets, playing sports, learning as muc...
# 3                                                NaN
# 4                                          good food
#
#                            Some of my hobbies are...  \
# 0  Soccer, traveling, fitness, spending time outside
# 1               Mountain biking, working out, gaming
# 2             Tennis, golf, basketball, poker, chess
# 3                                   Nature, podcasts
# 4                           hiking, painting, skiing
#
#                         I'm most excited to learn...  \
# 0  How to be more proficient in python and data s...
# 1                                   Machine Learning
# 2  How to transcend large data sets into meaningf...
# 3                                      Data Science!
# 4                        machine learning algorithms
#
#   Can we use your responses to this form for a class activity?  \
# 0                                                Yes
# 1                                                Yes
# 2                                Yes, but anonymized
# 3                                Yes, but anonymized
# 4                                                Yes
#
#          Any food allergies?  \
# 0                        NaN
# 1  Can't eat cow of pig meat
# 2                         No
# 3                        NaN
# 4                       Nope
#
#                              Any questions/concerns? First Name     Last Name  \
# 0                                                NaN      Henry       Brorsen
# 1                                                NaN    Venkata  Panchumarthy
# 2  Concerned that I may need a little bit of extr...       Whit         Stahl
# 3                                                NaN       Syed   Hasan-Aamir
# 4                                  Not at the moment  Francesca     Pirozzoli
#
#   Preferred name (if different)
# 0                           NaN
# 1                        Sujith
# 2                           NaN
# 3                         Ahmad
# 4                        Franny
#
# [5 rows x 22 columns]

# %% [markdown]
# Now we have all the data together. Let's get some more info about the columns of the dataframe

# %%
# Get info from the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 8
# Data columns (total 22 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Index                                                           9 non-null      int64
#  1   Timestamp                                                       9 non-null      object
#  2   Preferred Pronouns                                              9 non-null      object
#  3   What college are you in? (If not UVA, put your school)          8 non-null      object
#  4   What year are you?                                              8 non-null      object
#  5   My planned (or declared) major is... (Separate each by commas)  9 non-null      object
#  6   Are you new to CS                                               9 non-null      object
#  7   How I feel about... [Python]                                    9 non-null      object
#  8   How I feel about... [R]                                         9 non-null      object
#  9   How I feel about... [SQL]                                       9 non-null      object
#  10  How I feel about... [SAS/STATA]                                 9 non-null      object
#  11  How I feel about... [Other Languages]                           8 non-null      object
#  12  How I feel about... [Statistics]                                9 non-null      object
#  13  I'm passionate about...                                         7 non-null      object
#  14  Some of my hobbies are...                                       9 non-null      object
#  15  I'm most excited to learn...                                    9 non-null      object
#  16  Can we use your responses to this form for a class activity?    9 non-null      object
#  17  Any food allergies?                                             6 non-null      object
#  18  Any questions/concerns?                                         3 non-null      object
#  19  First Name                                                      9 non-null      object
#  20  Last Name                                                       9 non-null      object
#  21  Preferred name (if different)                                   3 non-null      object
# dtypes: int64(1), object(21)
# memory usage: 1.6+ KB

# %% [markdown]
# You'll notice that from the previous step, all of the columns are objects except Index. Let's change that and make the Index column a column of strings instead of integers

# %%
# Convert the Index column from ints to Strings
df['Index'] = df.Index.astype(str)

# %%
# See the changes by looking at the dataframe info again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 8
# Data columns (total 22 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Index                                                           9 non-null      object
#  1   Timestamp                                                       9 non-null      object
#  2   Preferred Pronouns                                              9 non-null      object
#  3   What college are you in? (If not UVA, put your school)          8 non-null      object
#  4   What year are you?                                              8 non-null      object
#  5   My planned (or declared) major is... (Separate each by commas)  9 non-null      object
#  6   Are you new to CS                                               9 non-null      object
#  7   How I feel about... [Python]                                    9 non-null      object
#  8   How I feel about... [R]                                         9 non-null      object
#  9   How I feel about... [SQL]                                       9 non-null      object
#  10  How I feel about... [SAS/STATA]                                 9 non-null      object
#  11  How I feel about... [Other Languages]                           8 non-null      object
#  12  How I feel about... [Statistics]                                9 non-null      object
#  13  I'm passionate about...                                         7 non-null      object
#  14  Some of my hobbies are...                                       9 non-null      object
#  15  I'm most excited to learn...                                    9 non-null      object
#  16  Can we use your responses to this form for a class activity?    9 non-null      object
#  17  Any food allergies?                                             6 non-null      object
#  18  Any questions/concerns?                                         3 non-null      object
#  19  First Name                                                      9 non-null      object
#  20  Last Name                                                       9 non-null      object
#  21  Preferred name (if different)                                   3 non-null      object
# dtypes: object(22)
# memory usage: 1.6+ KB

# %% [markdown]
# It looks like the column names are super long, which could be a problem down the line. Let's shorten them. So you don't have to write out a new name for each column, here's a list of new column names:
#
# 'index', 'timestamp', 'pronouns', 'college', 'year', 'major', 'cs_new', 'python_feel', 'r_feel', 'sql_feel', 'sas_feel', 'other_languages_feel', 'stats_feel', 'ds_interest', 'hobbies', 'first', 'last', 'nickname'

# %%
# Get the column names
df.columns
# Out:
# Index(['Index', 'Timestamp', 'Preferred Pronouns',
#        'What college are you in? (If not UVA, put your school)',
#        'What year are you?',
#        'My planned (or declared) major is... (Separate each by commas)',
#        'Are you new to CS', 'How I feel about... [Python]',
#        'How I feel about... [R]', 'How I feel about... [SQL]',
#        'How I feel about... [SAS/STATA]',
#        'How I feel about... [Other Languages]',
#        'How I feel about... [Statistics]', 'I'm passionate about...',
#        'Some of my hobbies are...', 'I'm most excited to learn...',
#        'Can we use your responses to this form for a class activity?',
#        'Any food allergies?', 'Any questions/concerns?', 'First Name',
#        'Last Name', 'Preferred name (if different)'],
#       dtype='object')

# %%
# Rename them to something better
df.columns = ['timestamp', 'index', 'college', 'year', 'major', 'cs_new', 'python_feel', 'r_feel', 'sql_feel', 'sas_feel', 'other_languages_feel', 'stats_feel', 'ds_interest', 'hobbies', 'first', 'last', 'nickname']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-dc7cc12c3ed0> in <module>
#       1 # Rename them to something better
# ----> 2 df.columns = ['timestamp', 'index', 'college', 'year', 'major', 'cs_new', 'python_feel', 'r_feel', 'sql_feel', 'sas_feel', 'other_languages_feel', 'stats_feel', 'ds_interest', 'hobbies', 'first', 'last', 'nickname']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 22 elements, new values have 17 elements

# %% [markdown]
# Take a look at the nicknames column. It seems like not that many people have nicknames. Let's find out exactly how many people don't have nicknames

# %%
# How many people don't have nicknames
df.nickname.isna().value_counts() #8 people with nicknames

# %% [markdown]
# To confuse Ishaan, the PCs decided to call everyone who doesn't have a preferred nickname Ishaan. Change the dataframe to reflect this.

# %%
# Replace empty fields in the nickname column to Ishaan
df['nickname'] = df.nickname.fillna('Ishaan')

# %% [markdown]
# Some people forgot to fill out the college field. Let's assume they go to Virginia Tech (ew)

# %%
# Assume that people who don't have a college go to Virginia Tech (VT)
df['college'] = df.college.fillna("VT :(")

# %% [markdown]
# Unfortunately, most colleges don't use the terms 1st year, 2nd year, 3rd year and 4th year. Make the data more accessible by changing the year data to freshman, sophomore, junior and senior (leave graduate school as is)

# %%
# Change the year names to what the plebs(jk) call them
df['year'] = df.year.replace({"1st Year":"Freshman", "2nd Year":"Sophomore", "3rd Year": "Junior", "4th Year": "Senior"})
df

# %% [markdown]
# Let's see how many people are CS majors. Unfortunately, people wrote in both CS and Computer Science. Check out the pandas documentation to see how you can check for both in the same line:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.contains.html

# %%
# Find out how students many are CS majors
df.major.str.contains('CS|Computer Science').value_counts()

# %% [markdown]
# It looks like a lot of people are doing 2 majors! Find out exactly how many students are double majoring

# %%
# Find out how many people are doing more than one major
df.major.str.split(', ').apply(lambda x: len(x) > 1).sum()

# %% [markdown]
# Pandas has a super cool object called datetime objects. Let's experiment with them a bit. First convert the timestamp column to datetime objects

# %%
# Convert the timestamps to datetime objects
df.timestamp = pd.to_datetime(df.timestamp)

# %% [markdown]
# Take a look at the features of the datetime objects. Use the day in the object to find out how many people who submitted on Sept. 12th.

# %%
# Find out how many people submitted this form on 09/12
df[df.timestamp.dt.day == 12].shape[0]

# %% [markdown]
# Now try figuring out how many people submitted the form just after the due date of Sept. 12th 5:00 PM [totally okay if this was you :P]

# %%
# Find out how many people submitted past the due date
df[df.timestamp > pd.Timestamp("09/12/21 17:00")].shape[0]
